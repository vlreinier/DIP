# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
pd.options.mode.chained_assignment = None

# %% [markdown]
# # FlickBike
#
# In dit notebook wordt een analyse uitgevoerd op een aantal bedrijfsprocessen en -vragen met het doel om een verbetering door te brengen in de processen. Door middel van statistiek en een aantal AI technieken bieden wij inzichten in de FlickBike dataset. Zo hopen we een goed plan/advies op te leveren waarin wij een aantal vragen die door FlickBike opgesteld zijn beantwoorden. In dit notebook zullen de volgende vragen naar voren komen en uitgewerkt worden in een logische volgorde.
#
# 1. Hoe voorspel je de groei van FlickBike? Hoe voorspel je het aantal verhuurde fietsen in bepaalde tijdspannes?
# 2. Hoe kan voorspeld worden op welke plekken fietstekorten kunnen ontstaan?
# 3. Hoe kan het minimaal benodigd aantal fietsen voorspeld of berekend worden (per locatie)?
#
# Door middel van datainzichten, grafieken en uitleg hopen wij een goed leesbaar verslag op te leveren. Voor het bedenken van verschillende modellen moet ook correlatie onderzoek uitgevoerd worden. Welke factoren hebben wel of geen invloed op het model? Verschillende factoren, zoals het weer, zijn meegenomen in het onderzoek naar passende modellen voor het bovenstaande vragen.

# %% [markdown]
# #### Data inlezen en voorbereiden

# %%
df_flickbike = pd.read_csv("bikes.csv")
df_flickbike["date"] = pd.to_datetime(df_flickbike["date"],format="%Y-%m-%d %H:%M:%S")
day_of_week = {0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}
df_flickbike['weekday'] = pd.to_datetime(df_flickbike['start_time']).dt.dayofweek.map(day_of_week)
df_flickbike.head()
# Out:
#    Unnamed: 0  tripid  userid  bikeid account  bikenumber  \
# 0           1   33838   13452     382      AR  6631000433
# 1           2   33839   13452     812      AR  6631000146
# 2           3   33851   13182     238      AR  6631000443
# 3           4   33852   13182     238      AR  6631000443
# 4           5   33867   12674     787      AG  6631000283
#
#             start_time             end_time  start_lat  start_lng    end_lat  \
# 0  2019-01-01 06:46:03  2019-01-01 06:46:03  52.296065   4.787667  52.296200
# 1  2019-01-01 06:47:39  2019-01-01 06:47:39  52.295938   4.788336  52.295940
# 2  2019-01-01 14:15:36  2019-01-01 14:15:36  52.307337   4.807633  52.307336
# 3  2019-01-01 14:33:50  2019-01-01 14:33:50  52.308478   4.809970  52.308537
# 4  2019-01-01 20:11:05  2019-01-01 20:11:05  52.506522   4.727323  52.506809
#
#     end_lng                date  weekday
# 0  4.787679 2019-01-01 06:46:00  Tuesday
# 1  4.788557 2019-01-01 06:47:35  Tuesday
# 2  4.807630 2019-01-01 14:15:32  Tuesday
# 3  4.810099 2019-01-01 14:33:46  Tuesday
# 4  4.732135 2019-01-01 20:11:01  Tuesday

# %% [markdown]
# ## Hoe voorspel je de groei van FlickBike ?
# #### In het bijzonder: hoe voorspel je het aantal verhuurde fietsen op de dagen tussen 10 december 2019 en 31 januari 2020?
#
# De groei van FlickBike is van veel factoren afhankelijk, zowel externe als interne factoren. Veel factoren zullen en/of kunnen niet meegenomen worden in het model omdat deze onberekenbaar, onbereikbaar of niet noemenswaardig zijn. Alle andere factoren die wel beschikbaar zijn moeten op correlatie onderzocht worden. Als bepaalde eigenschappen veel correlatie tonen met de target eigenschap, kunnen deze belangrijk zijn voor het model.
#
#
# Naast het correlatie onderzoek hebben we al wat ideeën opgedaan welke factoren we kunnen meenemen in ons model:
#     - Dag van de week
#     - seizoenen (vakantie seizoen moeten worden herkend door het model)
#     - Neerslag/temperatuur/zonnestraling
#     - Feestdagen (boolean)
#     - Dagdeel (bijvoorbeeld of er vroeg in de ochtend een fiets is gehuurd)
#     - Spitsuren per dag en per dagsdeel (in spitsuren pakken werknemers waarschijnlijk eerder de fiets dan de auto)
#         - De klassieke spitsuren meegeven als variabelen, of ...
#         - Clusters maken per dagdeel of per uur, hiermee schatten hoe druk het is, en dan drukte meegeven als variabele.
#     - drukte op straat of op het werk, per dag en per dagsdeel
#         - zelfde werkwijze als spitsuren
#         - (Drukte op straat zal geen invloed hebben op het gedrag van werknemers. Echter is er wel een verwachte correlatie: als het druk is in de stad is de kans ook groter dat werknemers de fiets pakken. Dit komt door variabelen die wij niet hard kunnen maken, maar die zeker aanwezig zijn. (Denk bijvoorbeeld aan corona virus, weinig mensen gaan de deur uit en weinig mensen pakken de fiets). )
#
# Voor een aantal factoren moet er meer data opgezocht worden en misschien zelfs onderzoek worden gedaan (bijvoorbeeld naar de correlatie tussen drukte/spits rondom schiphol). Een aantal bronnen zijn hiervoor opgezocht met API's die zowel historische als live data bevatten.
#
# drukte op de weg - https://www.ndw.nu/pagina/nl/103/datalevering/120/open_data/<br>
# drukte mensen op straat - https://www.cbs.nl/nl-nl/onze-diensten/innovatie/project/bewegingen-meten-met-anonieme-telefoondata (hier wordt data verzameld van telefoons die aan staan om drukte metingen te maken)
#
#
# Dit probleem kan lastig opgelost worden met classificatie. Er zal dan hoogstwaarschijnlijk overfitting plaatsvinden ivm het hoge aantal target features. Linear of Non-linear Regression gaat ervan uit dat er een continue directe correlatie aanwezig is tussen input en output. Echter is dit niet het geval met categoriale waarden die zeker meegenomen worden.
#
# Een van de modellen die gebruikt kan worden voor dit probleem is een decision tree regressor. Dit heeft te maken met voordelen als visualisatie en flexibiliteit, waarbij het laatste vooral belangrijk is om te werken met zowel kwantitatieve waarden (temperatuur) en categoriale waarden (dagen/seizoenen). Bovendien kan decision tree regressor gevalideerd worden met RMSE, dat nodig is het met andere modellen te vergelijken.
#
# Ook wordt er een kwantitatieve waarde als uitkomst verwacht. Met classificatie, zoals een normale desicion tree, wordt er een categoriale uitkomst gegenereerd, terwijl er bij DTR een continue waarde wordt berekend. Dit maakt de uitkomst accurater en gepaster voor de vraagstelling van FlickBike.

# %% [markdown]
# ### Hoe kunnen bepaalde factoren invloed hebben of krijgen op het model  ? Welke factoren hebben  daadwerkelijk invloed/correlatie?

# %% [markdown]
# #### Het weer
#
# Voor het gebruiken van weer moeten eerst een aantal weer factoren gekozen worden. Intuitief zouden bijvoorbeeld de neerslag een invloed kunnen hebben op de verhuur van fietsen ivm het feit dat mensen niet van houden om nat te regenen. Maar dit blijft een aanname. Er zal eerst een correlatie moeten worden gezocht tussen weerfactoren en verandering in fiets verhuur / gebruik. Gebruik makend van de KNMI weer api hebben we een aantal historische weer datapunten opgevraagd en opgeslagen. Voor nu doen we onderzoek naar invloed van neerslag, wind en temperatuur.

# %%
# Inlezen en voorbereiden weer dataset
df_weer = pd.read_csv("weer.csv")
df_weer["YYYYMMDD"] = pd.to_datetime(df_weer["YYYYMMDD"],format="%Y%m%d")
df_weer.drop(['STN', 'SQ'], axis=1, inplace=True)
df_weer.rename(columns={'YYYYMMDD':'date','FG':'windspeed','TG':'temperature','RH':'rain'},inplace=True)
df_weer.head()
# Out:
#         date  windspeed  temperature  rain
# 0 2019-01-01         76           77     5
# 1 2019-01-02         48           56    -1
# 2 2019-01-03         23           31    -1
# 3 2019-01-04         45           54    -1
# 4 2019-01-05         65           72     1

# %%
# Verhuurcijfers samenvoegen met weerdata
df_bikes_per_day = df_flickbike[["tripid"]].groupby([df_flickbike["date"].dt.date]).count()
df_bikes_per_day["day"] = pd.to_datetime(df_bikes_per_day.index,format="%Y-%m-%d %H:%M:%S")
df_weer_verhuur = df_weer.merge(df_bikes_per_day, how='left', left_on='date', right_on="day")
df_weer_verhuur.rename(columns={'tripid':'bikecount'},inplace=True)
df_weer_verhuur.head()
# Out:
#         date  windspeed  temperature  rain  bikecount        day
# 0 2019-01-01         76           77     5        8.0 2019-01-01
# 1 2019-01-02         48           56    -1       61.0 2019-01-02
# 2 2019-01-03         23           31    -1       90.0 2019-01-03
# 3 2019-01-04         45           54    -1       64.0 2019-01-04
# 4 2019-01-05         65           72     1       17.0 2019-01-05

# %%
# Correlatiematrix
df_weer_verhuur.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_b53ddc18_990a_11ea_bf3d_90324b94101erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow0_col2 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow1_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow1_col2 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow1_col3 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow2_col0 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow2_col1 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow2_col3 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow3_col1 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b53ddc18_990a_11ea_bf3d_90324b94101erow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_b53ddc18_990a_11ea_bf3d_90324b94101e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >windspeed</th>        <th class="col_heading level0 col1" >temperature</th>        <th class="col_heading level0 col2" >rain</th>        <th class="col_heading level0 col3" >bikecount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b53ddc18_990a_11ea_bf3d_90324b94101elevel0_row0" class="row_heading level0 row0" >windspeed</th>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow0_col1" class="data row0 col1" >-0.06</td>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow0_col2" class="data row0 col2" >0.29</td>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow0_col3" class="data row0 col3" >-0.21</td>
#             </tr>
#             <tr>
#                         <th id="T_b53ddc18_990a_11ea_bf3d_90324b94101elevel0_row1" class="row_heading level0 row1" >temperature</th>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow1_col0" class="data row1 col0" >-0.06</td>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow1_col1" class="data row1 col1" >1</td>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow1_col2" class="data row1 col2" >0.022</td>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow1_col3" class="data row1 col3" >0.18</td>
#             </tr>
#             <tr>
#                         <th id="T_b53ddc18_990a_11ea_bf3d_90324b94101elevel0_row2" class="row_heading level0 row2" >rain</th>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow2_col0" class="data row2 col0" >0.29</td>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow2_col1" class="data row2 col1" >0.022</td>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow2_col3" class="data row2 col3" >-0.0045</td>
#             </tr>
#             <tr>
#                         <th id="T_b53ddc18_990a_11ea_bf3d_90324b94101elevel0_row3" class="row_heading level0 row3" >bikecount</th>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow3_col0" class="data row3 col0" >-0.21</td>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow3_col1" class="data row3 col1" >0.18</td>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow3_col2" class="data row3 col2" >-0.0045</td>
#                         <td id="T_b53ddc18_990a_11ea_bf3d_90324b94101erow3_col3" class="data row3 col3" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Hieruit blijkt dat op het eerste gezicht weer gegevens weinig invloed hebben op het aantal verhuurde fietsen. De grootste correlatie is te zien bij windkracht met een negatieve correlatie van 0.2. Zelfs daar is dus praktisch geen correlatie te vinden. Misschien valt er een betere correlatie te behalen door meerdere variabelen te combineren en een LR model op te stellen, maar veel verbetering wordt hier niet verwacht.
#
# Een mogelijke reden voor de slechte correlatie kan te maken hebben met waar deze fietsen voor bedoeld zijn, namelijk als vervoer van en naar het werk. Zoals al gezegd is heeft dit niets te maken met woon-werk verkeer en wordt de fiets regelmatig gepakt om bijvoorbeeld wat eten te halen, maar toch worden werknemers meer gedwongen de fiets te pakken dan wanneer iemand in zijn vrije tijd de fiets pakt.
#
# Weer gegevens gaan we dus niet meenemen in de decision tree regressor. Mogelijk is er toch een verband te vinden door de data anders te transformeren of combineren, dus dit wordt de volgende stap. We gaan kijken of we de data zo kunnen selecteren dat er toch correlaties ontstaan. Bijvoorbeeld door te kijken naar specifieke locaties, of speciale omstandigheden.

# %% [markdown]
# #### Neerslag:

# %%
rain = df_weer_verhuur[['rain', 'bikecount']]

# %%
rain.sort_values("rain",inplace=True)
plt.scatter(rain["rain"],rain["bikecount"])
plt.title("Relatie regen en verhuurde fietsen")
plt.xlabel("Neerslag")
plt.ylabel("Aantal gebruikte fietsen")
plt.show()

# %%
rain.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_b56fb8a6_990a_11ea_b980_90324b94101erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b56fb8a6_990a_11ea_b980_90324b94101erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b56fb8a6_990a_11ea_b980_90324b94101erow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b56fb8a6_990a_11ea_b980_90324b94101erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_b56fb8a6_990a_11ea_b980_90324b94101e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rain</th>        <th class="col_heading level0 col1" >bikecount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b56fb8a6_990a_11ea_b980_90324b94101elevel0_row0" class="row_heading level0 row0" >rain</th>
#                         <td id="T_b56fb8a6_990a_11ea_b980_90324b94101erow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b56fb8a6_990a_11ea_b980_90324b94101erow0_col1" class="data row0 col1" >-0.0045</td>
#             </tr>
#             <tr>
#                         <th id="T_b56fb8a6_990a_11ea_b980_90324b94101elevel0_row1" class="row_heading level0 row1" >bikecount</th>
#                         <td id="T_b56fb8a6_990a_11ea_b980_90324b94101erow1_col0" class="data row1 col0" >-0.0045</td>
#                         <td id="T_b56fb8a6_990a_11ea_b980_90324b94101erow1_col1" class="data row1 col1" >1</td>
#             </tr>
#     </tbody></table>

# %%
rain[rain['rain'] > 60].corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_b5735f9a_990a_11ea_9f35_90324b94101erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b5735f9a_990a_11ea_9f35_90324b94101erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b5735f9a_990a_11ea_9f35_90324b94101erow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b5735f9a_990a_11ea_9f35_90324b94101erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_b5735f9a_990a_11ea_9f35_90324b94101e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rain</th>        <th class="col_heading level0 col1" >bikecount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5735f9a_990a_11ea_9f35_90324b94101elevel0_row0" class="row_heading level0 row0" >rain</th>
#                         <td id="T_b5735f9a_990a_11ea_9f35_90324b94101erow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b5735f9a_990a_11ea_9f35_90324b94101erow0_col1" class="data row0 col1" >0.098</td>
#             </tr>
#             <tr>
#                         <th id="T_b5735f9a_990a_11ea_9f35_90324b94101elevel0_row1" class="row_heading level0 row1" >bikecount</th>
#                         <td id="T_b5735f9a_990a_11ea_9f35_90324b94101erow1_col0" class="data row1 col0" >0.098</td>
#                         <td id="T_b5735f9a_990a_11ea_9f35_90324b94101erow1_col1" class="data row1 col1" >1</td>
#             </tr>
#     </tbody></table>

# %%
rain[rain['rain'] > 250].corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_b57691ca_990a_11ea_af43_90324b94101erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b57691ca_990a_11ea_af43_90324b94101erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b57691ca_990a_11ea_af43_90324b94101erow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b57691ca_990a_11ea_af43_90324b94101erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_b57691ca_990a_11ea_af43_90324b94101e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rain</th>        <th class="col_heading level0 col1" >bikecount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b57691ca_990a_11ea_af43_90324b94101elevel0_row0" class="row_heading level0 row0" >rain</th>
#                         <td id="T_b57691ca_990a_11ea_af43_90324b94101erow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b57691ca_990a_11ea_af43_90324b94101erow0_col1" class="data row0 col1" >0.46</td>
#             </tr>
#             <tr>
#                         <th id="T_b57691ca_990a_11ea_af43_90324b94101elevel0_row1" class="row_heading level0 row1" >bikecount</th>
#                         <td id="T_b57691ca_990a_11ea_af43_90324b94101erow1_col0" class="data row1 col0" >0.46</td>
#                         <td id="T_b57691ca_990a_11ea_af43_90324b94101erow1_col1" class="data row1 col1" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Hierboven zien we eerst dat er praktisch geen correlatie is tussen neerslag en aantal verhuurde fietsen. Als we de rijen met minder weinig neerslag verwijderen, hebben we opeens steeds meer correlatie.

# %% [markdown]
# #### Temperatuur:

# %%
temp = df_weer_verhuur[['temperature', 'bikecount']]

# %%
temp.sort_values("temperature",inplace=True)
plt.scatter(temp["temperature"],temp["bikecount"])
plt.title("Relatie temperatuur en verhuurde fietsen")
plt.xlabel("Temperatuur")
plt.ylabel("Aantal gebruikte fietsen")
plt.show()

# %%
temp.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_b59ab97e_990a_11ea_96dd_90324b94101erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b59ab97e_990a_11ea_96dd_90324b94101erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b59ab97e_990a_11ea_96dd_90324b94101erow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b59ab97e_990a_11ea_96dd_90324b94101erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_b59ab97e_990a_11ea_96dd_90324b94101e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >temperature</th>        <th class="col_heading level0 col1" >bikecount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b59ab97e_990a_11ea_96dd_90324b94101elevel0_row0" class="row_heading level0 row0" >temperature</th>
#                         <td id="T_b59ab97e_990a_11ea_96dd_90324b94101erow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b59ab97e_990a_11ea_96dd_90324b94101erow0_col1" class="data row0 col1" >0.18</td>
#             </tr>
#             <tr>
#                         <th id="T_b59ab97e_990a_11ea_96dd_90324b94101elevel0_row1" class="row_heading level0 row1" >bikecount</th>
#                         <td id="T_b59ab97e_990a_11ea_96dd_90324b94101erow1_col0" class="data row1 col0" >0.18</td>
#                         <td id="T_b59ab97e_990a_11ea_96dd_90324b94101erow1_col1" class="data row1 col1" >1</td>
#             </tr>
#     </tbody></table>

# %%
temp[temp['temperature'] < 50].corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_b59eaf7a_990a_11ea_bde4_90324b94101erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b59eaf7a_990a_11ea_bde4_90324b94101erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b59eaf7a_990a_11ea_bde4_90324b94101erow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b59eaf7a_990a_11ea_bde4_90324b94101erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_b59eaf7a_990a_11ea_bde4_90324b94101e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >temperature</th>        <th class="col_heading level0 col1" >bikecount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b59eaf7a_990a_11ea_bde4_90324b94101elevel0_row0" class="row_heading level0 row0" >temperature</th>
#                         <td id="T_b59eaf7a_990a_11ea_bde4_90324b94101erow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b59eaf7a_990a_11ea_bde4_90324b94101erow0_col1" class="data row0 col1" >0.19</td>
#             </tr>
#             <tr>
#                         <th id="T_b59eaf7a_990a_11ea_bde4_90324b94101elevel0_row1" class="row_heading level0 row1" >bikecount</th>
#                         <td id="T_b59eaf7a_990a_11ea_bde4_90324b94101erow1_col0" class="data row1 col0" >0.19</td>
#                         <td id="T_b59eaf7a_990a_11ea_bde4_90324b94101erow1_col1" class="data row1 col1" >1</td>
#             </tr>
#     </tbody></table>

# %%
temp[temp['temperature'] < 10].corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_b5a20786_990a_11ea_b66e_90324b94101erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b5a20786_990a_11ea_b66e_90324b94101erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b5a20786_990a_11ea_b66e_90324b94101erow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b5a20786_990a_11ea_b66e_90324b94101erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_b5a20786_990a_11ea_b66e_90324b94101e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >temperature</th>        <th class="col_heading level0 col1" >bikecount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5a20786_990a_11ea_b66e_90324b94101elevel0_row0" class="row_heading level0 row0" >temperature</th>
#                         <td id="T_b5a20786_990a_11ea_b66e_90324b94101erow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b5a20786_990a_11ea_b66e_90324b94101erow0_col1" class="data row0 col1" >0.52</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a20786_990a_11ea_b66e_90324b94101elevel0_row1" class="row_heading level0 row1" >bikecount</th>
#                         <td id="T_b5a20786_990a_11ea_b66e_90324b94101erow1_col0" class="data row1 col0" >0.52</td>
#                         <td id="T_b5a20786_990a_11ea_b66e_90324b94101erow1_col1" class="data row1 col1" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Wat voor neerslag geldt, geldt ook voor temperatuur. Als de weersomstandigheden koud en nat zijn, worden er dus minder fietsen gehuurd.

# %% [markdown]
# #### Windsnelheid:

# %%
wind = df_weer_verhuur[['windspeed', 'bikecount']]

# %%
wind.sort_values("windspeed",inplace=True)
plt.scatter(wind["windspeed"],wind["bikecount"])
plt.title("Relatie windsnelheid en verhuurde fietsen")
plt.xlabel("Windsnelheid")
plt.ylabel("Aantal gebruikte fietsen")
plt.show()

# %%
wind.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_
.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_b5d40cae_990a_11ea_b073_90324b94101erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b5d40cae_990a_11ea_b073_90324b94101erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b5d40cae_990a_11ea_b073_90324b94101erow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b5d40cae_990a_11ea_b073_90324b94101erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_b5d40cae_990a_11ea_b073_90324b94101e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >windspeed</th>        <th class="col_heading level0 col1" >bikecount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5d40cae_990a_11ea_b073_90324b94101elevel0_row0" class="row_heading level0 row0" >windspeed</th>
#                         <td id="T_b5d40cae_990a_11ea_b073_90324b94101erow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b5d40cae_990a_11ea_b073_90324b94101erow0_col1" class="data row0 col1" >-0.075</td>
#             </tr>
#             <tr>
#                         <th id="T_b5d40cae_990a_11ea_b073_90324b94101elevel0_row1" class="row_heading level0 row1" >bikecount</th>
#                         <td id="T_b5d40cae_990a_11ea_b073_90324b94101erow1_col0" class="data row1 col0" >-0.075</td>
#                         <td id="T_b5d40cae_990a_11ea_b073_90324b94101erow1_col1" class="data row1 col1" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Bij windsnelheid lijkt de correlatie meer op toeval berust dan op een werkelijk verband.

# %% [markdown]
# #### Dag van de week
#
# De dag van de week kan ook zeer sterke correlatie hebben met het aantal gebruikte huurfietsen. Je zou zeggen dat doordeweeks meer fietsen gebruikt worden omdat veel mensen alleen doordeweeks werken. Door de dag van de week als integer (1-7) of als string (ma-su) kan een nieuwe kolom met data aan het verhuurbestand toegevoegd worden.

# %%
value_counts = df_flickbike['weekday'].value_counts()
plt.figure(figsize=(10,6))
plt.ylabel('aantal fietsen gehuurd')
plt.xlabel('dagen van de week')
plt.title('Aantal verhuurde fietsen per weekdag')
plt.bar(value_counts.keys(), value_counts.values)
plt.show()

# %% [markdown]
# Uit bovenstaande grafiek kunnen we concluderen dat er vooral doordeweeks gebruik wordt gemaakt van de huurfietsen. Hierdoor kunnen we aannemen dat de fietsen vooral door doordeweeks werkende of scholende mensen wordt gebruikt.

# %% [markdown]
# #### Seizoenen

# %%
seasons = {1:'Winter', 2:'Lente', 3:'Zomer', 4:'Herfst'}
df_flickbike['season'] = df_flickbike['date'].apply(lambda x: (x.month%12 + 3) // 3).map(seasons)
df_flickbike['season'] = df_flickbike['season']
value_counts = df_flickbike['season'].value_counts()
plt.figure(figsize=(10,6))
plt.ylabel('aantal fietsen gehuurd')
plt.xlabel('seizoen')
plt.title('Aantal verhuurde fietsen per seizoen')
plt.bar(value_counts.keys(), value_counts.values)
plt.show()

# %% [markdown]
# Zoals in de bovenstaande grafiek is te zien, worden er de minste fietsen in de winter gebruikt.

# %% [markdown]
# #### Bijzondere dagen
#
# Bijzondere dagen kunnen als boolean waarde opgeslagen worden in de dataset. Om de data expansie zo gering mogelijk te houden kunnen bepaalde groepen van bijzondere dagen als gecombineerde waarde bij de dataset gevoegd worden. Dit voorkomt het plaatsen van boolean waardes voor elke bijzondere dag. De groepering kan door bijvoorbeeld een cluster algoritme gemaakt worden waarbij de groepen worden gemaakt op basis van overkeenkomsten in relatie tot de target feature(s)

# %% [markdown]
# #### Eventuele andere factoren
#
# Eventuele factoren om mee te nemen zijn:
# - concurrenten die de markt opeisen
# - financiele of medische crisissen
# - bedrijfs/personeels veranderingen/problemen
# - Seizoenen

# %% [markdown]
# ## Hoe kan voorspeld worden op welke plekken fietstekorten kunnen ontstaan
#
# Het is lastig om te voorspellen wanneer er tekorten ontstaan. Je weet immers nooit of iemand ergens een fiets misloopt. Een soort van feedback systeem zou misschien inzicht geven in waar mensen vaak geen fiets kunnen vinden. Ook kan je niet zien hoelang iemand naar een fiets heeft gezocht of hoelang deze persoon ervoor heeft moeten lopen.<br><br>
#
#
# <i>
# Wel kan gekeken worden naar plekken waar veel fietsen worden gebruikt. Met andere woorden, in welk gebied wordt het meest een fiets gepakt en waar wordt het meest gefietst, hotspots. Door te kijken naar het fietsgebruik op bepaalde routes en in bepaalde omgevingen kan een schatting gemaakt worden waar fietsen hotspots liggen.
# </i>
#
# Wel kan gekeken worden naar de begin- en eindcoördinaten van gehuurde fietsen. Dit zijn coördinaten van plekken waar mensen de fiets hebben ge(un)locked en dus waar mensen de fiets hebben gepakt. Hier kan een cluster analyse over worden uitgevoerd, om plekken te definieren waar de meeste fietsreizen zijn begonnen, en dus waar de meeste fietsen gevonden zijn. Als het goed is zullen de clusters zich dicht bij bedrijven en winkels plaatsvinden.
# We zullen alleen begincoördinaten pakken aangezien eindcoördinaten altijd de begincoördinaten zijn voor de volgende keer dat die fiets wordt gebruikt.
#
# Om deze hotspots te vinden is het nodig om met coordinaten te werken. Als eerst kan gekeken worden naar de hoeveelheid fietsen die weer terug komt op de plek van vertrek. Dit kunnen mogelijke hotspots zijn. Daarnaast kan gekeken worden naar het aantal fietsen per plek. Om te werken met coordinaten moet een afstandsfunctie of grids worden gebruikt.
#
# Om te hotspots te vinden kunnen verschillende methodes worden gebruikt. De data kan bijvoorbeeld op coordinates geclustered worden met een algoritme zoals KMeans (waarbij het soms lastig te bepalen is of het resultaat goed is). Ook kunnen grids van coordinates vastgesteld worden om zo gebieden te creeren waarin het aantal fietsen geteld kan worden (waarbij het 'edge' probleem optreedt waardoor informatie uit belangrijke combinaties van grids verloren gaan).
#
# Als de hotspots bekend zijn, kan gekeken worden hoeveel fietsen er gepakt zijn in een bepaald tijdspanne in de omgeving van deze hotspots. Als er veel fietsen zijn gepakt in een bepaalde omgeving kan dit een mogelijk komend tekort tot gevolg hebben.
# Als er een documentatie wordt bijgehouden van het aantal beschikbare fietsen op bepaalde hotspots, kan een bij en af registratie van fietsen in een bepaald gebied worden bijgehouden.
#
# Als laatst kan ook nog gekeken worden naar plekken waar weinig fietsen gebruikt worden maar waarbij wel zeer consistent alle of bijna alle fietsen worden gebruikt over een bepaalde periode. Mogelijk kan het toevoegen van een paar fietsen de missers opvullen.

# %%
plt.title("places where bikes were unlocked (50 bikes)")
plt.title("places where bikes were unlocked (2000 bikes)")
plt.xlabel("Longitude"),plt.ylabel("Latitude")
plt.plot(df_flickbike["start_lat"].head(50),df_flickbike["start_lng"].head(50),"ro")
plt.show()

# %% [markdown]
# Bij kleine aantallen zijn er groepen te herkennen, zo kun je het punt rechtsonder negeren en zal in ieder geval gekeken moeten worden naar de cluster rond 52.3 lat en 4.8 long. Echter zijn de resultaten minder goed categoriseerbaar wanneer je grote aantallen meeneemt:

# %%
plt.title("places where bikes were unlocked (2000 bikes)")
plt.xlabel("Longitude"),plt.ylabel("Latitude")
plt.plot(df_flickbike["start_lat"].head(2000),df_flickbike["start_lng"].head(2000),"ro")
plt.show()

# %% [markdown]
# We zouden hier 2 clusters van kunnen maken, maar de clusters zijn zodanig groot waardoor we geen specifieke risicogebieden kunnen aanduiden. Het valt wel op dat het verschil tussen de eerste 50 fietsen een ander en nauwkeuriger onderscheid lijkt te maken dan die van 2000 fietsen.

# %%
fig2 = plt.figure(constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=5, nrows=4, figure=fig2)

for i in range(1,8):
    if i<=4:
        x,y = [0,i]
    else:
        x,y = [1,i-4]
    sp = fig2.add_subplot(spec2[x,y])
    df_bikes_weekday = df_flickbike[df_flickbike["date"].dt.weekday==i-1]
    sp.plot(df_bikes_weekday["start_lat"],df_bikes_weekday["start_lng"],"ro")
    plt.title("weekday "+str(i-1))

# %% [markdown]
# Hier zien we dat clusters afhankelijk zijn van de soort dag. Zo gaan werknemers op woensdag misschien naar een kraampje dat alleen woensdag open is. Door clusters te onderscheiden per dag kunnen we gebieden iets preciezer bepalen en kunnen we per dag aangeven hoe goed deze clusters zijn.

# %% [markdown]
# ## Hoe bereken je het minimaal aantal fietsen dat nodig is ?
#
# <i>
# Om erachter te komen wat het minimaal aantal fietsen is dat nodig is, is het handig om te weten wanneer fietsen wel en niet gebruikt worden. Wij hebben begrepen dat alleen de gebruikte fietsen in de dataset staan, dat wil zeggen, fietsen waarbij het slot open en weer dicht gedaan is. Daarmee is het lastig om te bepalen of er nou een fietstekort is of een teveel aan fietsen. Als kan berekend worden wat de tijd is dat fietsen stil liggen en niet gebruikt worden, kan ook gekeken worden hoeveel fietsen uiteindelijk nodig zijn. Daarom hebben we nog wat meer informatie over de dataset nodig.</i>
#
# Om erachter te komen wat het minimaal aantal fietsen is dat nodig is, is het handig om te weten wanneer fietsen wel en niet gebruikt worden. Wij hebben begrepen dat de gebruikte fietsen in de dataset staan, dat wil zeggen, fietsen waarbij het slot open en weer dicht gedaan is. Niet gebruikte fietsen zijn ook te classificeren. Elke fiets heeft een uniek nummer. Het verschil tussen eindtijd en de opvolgende begintijd van de huur van een unieke fiets zegt ons hoelang een fiets beschikbaar is geweest. De begincoördinaten van de eindtijd geeft dan aan op welke plek een fiets beschikbaar is.
#
# Met onze aanname dat de bepaalde hotspots de beste keuze is, kunnen we kijken hoeveel fietsen er worden gehuurd binnen die hotspots. Het minimaal aantal fietsen moet de pieken binnen deze hotspots kunnen opvangen. Wel moet er nog rekening gehouden worden dat introduceren van parking zones het aantal verhuurde fietsen op hotspots verhoogd. Dit is een probleem die we niet met historische data kunnen oplossen.
#
# <i>
# Daarnaast kan er ook naar hotspots gekeken worden. Als er een gemiddeld aantal gebruikte fietsen per dag kan worden vastgesteld op een bepaalde plek, kan gekeken worden hoeveel fietsen er werkelijk nodig zijn. Er kan bijvoorbeeld voor een aantal hotspots een minimaal aantal beschikbare fietsen per seizoen of periode vastgesteld worden.
#     </i>

# %%
boxplot = df_bikes_per_day.boxplot(column=['tripid'])

# %% [markdown]
# Hier zien we dat
# - gemiddeld 170 fietsen per dag worden verhuurd.
# - Op 75% van de dagen worden minder dan 220 fietsen worden verhuurd.
#
# 75% is misschien wat aan de lage kant als we spreken over pieken. Natuurlijk ligt het woord bij flickbike wanneer het gaat om het definieren van pieken, maar laten we voor nu 95% nemen

# %%
aantal_dagen = []
tot_len=len(df_bikes_per_day)
for i in range(0,500,5):
    aantal_dagen.append( len(df_bikes_per_day[df_bikes_per_day["tripid"]>i])/tot_len)
plt.plot([i for i in range(0,500,5)],aantal_dagen)
plt.title("percentage hoevaak minimaal x aantal verhuurde fietsen voor komt op 1 dag")
plt.ylabel("kans in %")
plt.xlabel("aantal fietsen")
# Out:
# Text(0.5, 0, 'aantal fietsen')

# %%
for i,j in zip(aantal_dagen,[i for i in range(0,500,5)]):
    if i<0.05:
        print(j)
        break
# Out:
# 310

# %% [markdown]
# Om 95% van de dagen voldoende fietsen te verhuren moet elke dag, of op een slimmere manier per dag verschillend, 350 fietsen beschikbaar zijn.

# %% [markdown]
# ## Hoe wordt alles gevisualiseerd?
#
# <b>Model</b> <br>
# Desicion tree regressor kan makkelijk worden gevisualiseerd met scykit learn. Hierbij worden de beslissingen duidelijk getoond. Voor het valideren laten we het verschil zien tussen voorspelde waardes en werkelijke waardes.
#
# <b>Data analyses</b>  <br>
# Door de huur van fietsen te visualiseren door de tijd heen kan er patronen herkend worden. Zo verwachten we een periodieke beweging dat veroorzaakt wordt door seizoenen.
# Verder gaan we in een plot clusters van longitude en latitude visualiseren om hiermee op blote oog plekken te herkennen waar veel gefietst wordt. Als er duidelijk clusters voorkomen kan er een classificatie model getraind worden waarmee drukke plekken herkend kunnen worden. Dan weten we ook waar er eventueel een tekort aan fietsen is.
#
# <b>Deelvragen </b>  <br>
# Invloeden van het weer zijn al gedeeltelijk gevisualiseerd. Er zijn plots gemaakt waarin de relatie tussen verhuur en weervariabele te herkennen is. Ook is er een correlatiematrix gemaakt.
# Tekorten voorkomen wordt op dezelfde manier in een plot getoond waar de pieken zitten, en in dezelfde plot laten we zien hoeveel fietsen beschikbaar zijn.

# %% [markdown]
# ## Bijzondere dagen

# %%
import list_holidays as hd

# %%
holidays, vacations = hd.holidays(), hd.vacations()

# %%
vacations

# %%
df_flickbike_bijzonder = df_flickbike.copy()
df_flickbike_bijzonder["vakantie"]="geen"
df_flickbike_bijzonder["feestdag"]="geen"


df_flickbike_bijzonder.head()
# Out:
#    Unnamed: 0  tripid  userid  bikeid account  bikenumber  \
# 0           1   33838   13452     382      AR  6631000433
# 1           2   33839   13452     812      AR  6631000146
# 2           3   33851   13182     238      AR  6631000443
# 3           4   33852   13182     238      AR  6631000443
# 4           5   33867   12674     787      AG  6631000283
#
#             start_time             end_time  start_lat  start_lng    end_lat  \
# 0  2019-01-01 06:46:03  2019-01-01 06:46:03  52.296065   4.787667  52.296200
# 1  2019-01-01 06:47:39  2019-01-01 06:47:39  52.295938   4.788336  52.295940
# 2  2019-01-01 14:15:36  2019-01-01 14:15:36  52.307337   4.807633  52.307336
# 3  2019-01-01 14:33:50  2019-01-01 14:33:50  52.308478   4.809970  52.308537
# 4  2019-01-01 20:11:05  2019-01-01 20:11:05  52.506522   4.727323  52.506809
#
#     end_lng                date  weekday  season vakantie feestdag
# 0  4.787679 2019-01-01 06:46:00  Tuesday  Winter     geen     geen
# 1  4.788557 2019-01-01 06:47:35  Tuesday  Winter     geen     geen
# 2  4.807630 2019-01-01 14:15:32  Tuesday  Winter     geen     geen
# 3  4.810099 2019-01-01 14:33:46  Tuesday  Winter     geen     geen
# 4  4.732135 2019-01-01 20:11:01  Tuesday  Winter     geen     geen

# %%
for i in vacations:
    df_flickbike_bijzonder["vacation"][df_flickbike_bijzonder["date"].dt.date.isin(vacations[i])]=i
    

for i in holidays:
    df_flickbike_bijzonder["holiday"][df_flickbike_bijzonder["date"].dt.date.isin(holidays[i])]=i
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-07c0c2ba93b6> in <module>
# ----> 1 for i in vacations:
#       2     df_flickbike_bijzonder["vacation"][df_flickbike_bijzonder["date"].dt.date.isin(vacations[i])]=i
#       3
#       4
#       5 for i in holidays:
#
# TypeError: 'NoneType' object is not iterable

# %%
df_flickbike_bijzonder
# Out:
#        Unnamed: 0  tripid  userid  bikeid account  bikenumber  \
# 0               1   33838   13452     382      AR  6631000433
# 1               2   33839   13452     812      AR  6631000146
# 2               3   33851   13182     238      AR  6631000443
# 3               4   33852   13182     238      AR  6631000443
# 4               5   33867   12674     787      AG  6631000283
# 5               6   33869   14097     260      AR  6631000428
# 6               7   33870   13452     812      AR  6631000146
# 7               8   33871   13182     238      AR  6631000443
# 8               9   33872   13937    1242      AR  6631000297
# 9              10   33875   13683    1231      BG  6631000118
# 10             11   33877   13705     822      AG  6631000175
# 11             12   33884   12865     486      AR  6631000653
# 12             13   33885   12597     513      AR  6631000668
# 13             14   33890   12746     550      AR  6631000358
# 14             15   33893   13945     998      BG  6631000461
# 15             16   33894   12549     384      AR  6631000989
# 16             17   33900   12774     489      AR  6631000712
# 17             18   33905   12725    1021      AR  6631000884
# 18             19   33908   12936     605      AT  6631000295
# 19             20   33910   13388     196      AR  6631000779
# 20             21   33911   12936     605      AT  6631000295
# 21             22   33914   13205     246      AR  6631000416
# 22             23   33915   12528     550      AR  6631000358
# 23             24   33916   12528     252      AR  6631000389
# 24             25   33917   13205     246      AR  6631000416
# 25             26   33918   13913     605      AR  6631000295
# 26             27   33925   12528     252      AR  6631000389
# 27             28   33926   12754     853      AT  6631000927
# 28             29   33934   13453     252      AR  6631000389
# 29             30   33935   13708     802      AR  6631000303
# ...           ...     ...     ...     ...     ...         ...
# 50347       50348  168507   24766     894      AT  6631000620
# 50348       50349  168509   25983     691      AR  6631000270
# 50349       50350  168510   13945     335      BG  6631000089
# 50350       50351  168511   27299     306      AR  6631000665
# 50351       50352  168512   26338     757      AR  6631000327
# 50352       50353  168515   12805     202      AR  6631000794
# 50353       50354  168518   18364    1263      AR  6631000522
# 50360  52.300219  4.794258 2019-12-09 18:17:56     Monday  Winter
# 50361  52.306211  4.807673 2019-12-09 18:19:26     Monday  Winter
# 50362  52.297205  4.789963 2019-12-09 18:25:44     Monday  Winter
# 50363  52.291432  4.818540 2019-12-09 18:26:09     Monday  Winter
# 50364  52.304953  4.798865 2019-12-09 19:21:18     Monday  Winter
# 50365  52.297264  4.790927 2019-12-09 19:33:58     Monday  Winter
# 50366  52.304635  4.843451 2019-12-09 19:48:45     Monday  Winter
# 50367  52.305110  4.800165 2019-12-09 21:29:07     Monday  Winter
# 50368  52.305039  4.800256 2019-12-09 21:36:44     Monday  Winter
# 50369  52.307789  4.806709 2019-12-09 21:48:56     Monday  Winter
# 50370  52.295479  4.782799 2019-12-09 21:59:12     Monday  Winter
# 50371  52.307692  4.806554 2019-12-09 22:45:16     Monday  Winter
# 50372  52.307746  4.806697 2019-12-09 22:45:21     Monday  Winter
# 50373  52.307658  4.800519 2019-12-09 23:01:57     Monday  Winter
# 50374  52.307642  4.800440 2019-12-09 23:13:03     Monday  Winter
# 50375  52.307784  4.807289 2019-12-09 23:27:44     Monday  Winter
# 50376  52.296061  4.789163 2019-12-09 23:40:59     Monday  Winter
#
#              vakantie       feestdag
# 0      kerst_vakantie  nieuwjaarsdag
# 1      kerst_vakantie  nieuwjaarsdag
# 2      kerst_vakantie  nieuwjaarsdag
# 3      kerst_vakantie  nieuwjaarsdag
# 4      kerst_vakantie  nieuwjaarsdag
# 5      kerst_vakantie  nieuwjaarsdag
# 6      kerst_vakantie  nieuwjaarsdag
# 7      kerst_vakantie  nieuwjaarsdag
# 8      kerst_vakantie           geen
# 9      kerst_vakantie           geen
# 10     kerst_vakantie           geen
# 11     kerst_vakantie           geen
# 12     kerst_vakantie           geen
# 13     kerst_vakantie           geen
# 14     kerst_vakantie           geen
# 15     kerst_vakantie           geen
# 16     kerst_vakantie           geen
# 17     kerst_vakantie           geen
# 18     kerst_vakantie           geen
# 19     kerst_vakantie           geen
# 20     kerst_vakantie           geen
# 21     kerst_vakantie           geen
# 22     kerst_vakantie           geen
# 23     kerst_vakantie           geen
# 24     kerst_vakantie           geen
# 25     kerst_vakantie           geen
# 26     kerst_vakantie           geen
# 27     kerst_vakantie           geen
# 28     kerst_vakantie           geen
# 29     kerst_vakantie           geen
# ...               ...            ...
# 50347            geen           geen
# 50348            geen           geen
# 50349            geen           geen
# 50350            geen           geen
# 50351            geen           geen
# 50352            geen           geen
# 50353            geen           geen
# 50354            geen           geen
# 50355            geen           geen
# 50356            geen           geen
# 50357            geen           geen
# 50358            geen           geen
# 50359            geen           geen
# 50360            geen           geen
# 50361            geen           geen
# 50362            geen           geen
# 50363            geen           geen
# 50364            geen           geen
# 50365            geen           geen
# 50366            geen           geen
# 50367            geen           geen
# 50368            geen           geen
# 50369            geen           geen
# 50370            geen           geen
# 50371            geen           geen
# 50372            geen           geen
# 50373            geen           geen
# 50374            geen           geen
# 50375            geen           geen
# 50376            geen           geen
#
# [50377 rows x 17 columns]

# %%
bijzonder[0].date()
# Out:
# datetime.date(2019, 1, 1)
